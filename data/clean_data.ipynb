# %% [markdown]
# ### Bereinigen der Daten und zusammenführen der Tabellen

# %%
import pandas as pd
from dateutil.relativedelta import relativedelta
from datetime import datetime, timedelta, date
from pathlib import Path
import os
from dateutil.parser import parse
import locale

# %% [markdown]
# ### Daten 2018
#
# Funktion erstellen um auf den Ordner src zuzugreifen

# %%
def get_src_directory(script_directory):
    src_directory = script_directory.parent / 'src'
    return src_directory

# %% [markdown]
# Excel Datei einlesen und bereinigen

# %%
notebook_directory = os.getcwd()
script_directory = Path(notebook_directory)
src_directory = get_src_directory(script_directory)
file_path_18 = src_directory / 'Zaehlstelle_Neutor_2018_Stundenauswertung.xlsx'
neutor_xlsx_18 = pd.read_excel(file_path_18, 
                                sheet_name=None, 
                                skiprows=2,
                                skipfooter=1,
                                engine='openpyxl')

# %% [markdown]
# Bereinigungsschritte:<br>
# >    1. Spalten entfernen die nicht benötigt werden
# >    2. Datum trennen in Uhrzeit und formatieres Datum

# %%
notebook_directory = os.getcwd()
script_directory = Path(notebook_directory)
src_directory = get_src_directory(script_directory)
file_path_18 = src_directory / 'Zaehlstelle_Neutor_2018_Stundenauswertung.xlsx'
neutor_xlsx_18 = pd.read_excel(file_path_18, 
                                sheet_name=None, 
                                skiprows=2,
                                skipfooter=1,
                                engine='openpyxl')

df_neutor_18 = pd.concat(neutor_xlsx_18.values(), ignore_index=True)

df_neutor_18.drop('Gefühlte Temperatur (°C)', axis=1)
df_neutor_18.drop(columns='Gefühlte Temperatur (°C)', axis=1)
df_neutor_18 = df_neutor_18.drop(columns='Unnamed: 0')

df_neutor_18[['day', 'month', 'year', 'Uhrzeit']] = df_neutor_18['Zeit'].str.split(' ', expand=True)

month_to_num = {'Jan.': 1, 'Febr.': 2, 'Mrz.': 3, 'Apr.': 4, 'Mai': 5, 'Jun.': 6, 'Jul.': 7, 'Aug.': 8, 'Sept.': 9, 'Okt.': 10, 'Nov.': 11, 'Dez.': 12}
df_neutor_18.month = df_neutor_18.month.map(month_to_num)
df_neutor_18.day = df_neutor_18.day.astype(str)
df_neutor_18.day = df_neutor_18.day.str.replace('.','')

df_neutor_18.drop(['Zeit'], axis=True, inplace=True)
df_neutor_18['Zeit'] = pd.to_datetime(df_neutor_18['Uhrzeit'], format='%H:%M', errors='coerce').dt.time
#df_neutor_18['Zeit'] = df_neutor_18['Zeit'].astype('time')
df_neutor_18['Datum'] = pd.to_datetime(df_neutor_18[['year', 'month', 'day']])

df_neutor_18.drop(['day','month','year'], axis=True, inplace=True)

cols_18 = list(df_neutor_18.columns.values)
df_neutor_18 = df_neutor_18[['Datum', 'Zeit', 'Neutor (gesamt)', 'Neutor FR stadteinwärts', 'Neutor FR stadtauswärts', 'Wetter', 'Temperatur (°C)', 
                            'Luftfeuchtigkeit (%)', 'Regen (mm)', 'Wind (km/h)']]

df_neutor_names = list(df_neutor_18.columns.values)

df_neutor_18

print(cols_18)
# Out:
# ['Neutor (gesamt)', 'Neutor FR stadteinwärts', 'Neutor FR stadtauswärts', 'Wetter', 'Temperatur (°C)', 'Luftfeuchtigkeit (%)', 'Gefühlte Temperatur (°C)', 'Regen (mm)', 'Wind (km/h)', 'Uhrzeit', 'Zeit', 'Datum']

# %% [markdown]
# ### Daten 2019

# %%
file_path_19 = src_directory / 'Zaehlstelle_Neutor_2019_Stundenauswertung.xlsx'
neutor_xlsx_19 = pd.read_excel(file_path_19, 
                                sheet_name=None, 
                                skiprows=2,
                                skipfooter=1,
                                engine='openpyxl')

df_neutor_19 = pd.concat(neutor_xlsx_19.values(), ignore_index=True)

df_neutor_19 = df_neutor_19.drop(columns='Unnamed: 0')

print(df_neutor_19['Zeit'].dtype)

df_neutor_19['Datum'] = pd.to_datetime(df_neutor_19['Zeit'], format='%Y-%m-%d').dt.date.astype(str)
df_neutor_19['Zeit'] = pd.to_datetime(df_neutor_19['Zeit']).dt.time


cols_19 = list(df_neutor_19.columns.values)
df_neutor_19 = df_neutor_19[['Datum', 'Zeit', 'Neutor', 'FR stadteinwärts', 'FR stadtauswärts', 'Wetter', 'Temperatur (°C)',
                            'Luftfeuchtigkeit (%)', 'Regen (mm)', 'Wind (km/h)']]

df_neutor_19.columns = df_neutor_names

df_neutor_19
# Out:
# datetime64[ns]
#            Datum      Zeit  Neutor (gesamt)  Neutor FR stadteinwärts
# 0     2019-01-01  00:00:00               88                       26  \
# 1     2019-01-01  01:00:00              197                       57
# 2     2019-01-01  02:00:00              302                       94
# 3     2019-01-01  03:00:00              302                      121
# 4     2019-01-01  04:00:00              328                      119
# ...          ...       ...              ...                      ...
# 8753  2019-12-31  18:00:00              360                      198
# 8754  2019-12-31  19:00:00              351                      209
# 8755  2019-12-31  20:00:00              192                      104
# 8756  2019-12-31  21:00:00              120                       64
# 8757  2019-12-31  22:00:00              119                       67
#
#       Neutor FR stadtauswärts                   Wetter  Temperatur (°C)
# 0                          62  Stellenweiser Regenfall                8  \
# 1                         140  Stellenweiser Regenfall                8
# 2                         208                  Bedeckt                8
# 3                         181                  Bedeckt                8
# 4                         209                  Bedeckt                8
# ...                       ...                      ...              ...
# 8753                      162           Leicht bewölkt                4
# 8754                      142           Leicht bewölkt                3
# 8755                       88           Leicht bewölkt                3
# 8756                       56           Leicht bewölkt                2
# 8757                       52           Leicht bewölkt                2
#
#       Luftfeuchtigkeit (%)  Regen (mm)  Wind (km/h)
# 0                       90           0           20
# 1                       89           0           21
# 2                       88           0           23
# 3                       87           0           24
# 4                       87           0           25
# ...                    ...         ...          ...
# 8753                    93           0            4
# 8754                    93           0            4
# 8755                    93           0            3
# 8756                    94           0            3
# 8757                    94           0            4
#
# [8758 rows x 10 columns]

# %% [markdown]
# ### Daten 2020

# %%
file_path_20 = src_directory / 'Zaehlstelle_Neutor_2020_Stundenauswertung.xlsx'
neutor_xlsx_20 = pd.read_excel(file_path_20, 
                            sheet_name=None, 
                            skiprows=2,
                            skipfooter=1,
                            engine='openpyxl')

df_neutor_20 = pd.concat(neutor_xlsx_20.values(), ignore_index=True)

df_neutor_20 = df_neutor_20.drop(columns='Unnamed: 0')
    
#df_neutor['Datum'] = datetime.strftime(df_neutor['Zeit'], '%Y-%m-%d')
df_neutor_20['Datum'] = pd.to_datetime(df_neutor_20['Zeit'], format='%Y-%m-%d').dt.date.astype(str)
df_neutor_20['Zeit'] = pd.to_datetime(df_neutor_20['Zeit']).dt.time

cols_20 = list(df_neutor_20.columns.values)

df_neutor_20 = df_neutor_20[['Datum', 'Zeit', 'Neutor', 'Neutor FR stadteinwärts', 'Neutor FR stadtauswärts', 'Wetter', 'Temperatur (°C)',
                             'Luftfeuchtigkeit (%)', 'Regen (mm)', 'Wind (km/h)']]

df_neutor_20.columns = df_neutor_names

df_neutor_20
# Out:
#            Datum      Zeit  Neutor (gesamt)  Neutor FR stadteinwärts
# 0     2020-01-01  00:00:00            110.0                     47.0  \
# 1     2020-01-01  01:00:00            177.0                     78.0
# 2     2020-01-01  02:00:00            258.0                    116.0
# 3     2020-01-01  03:00:00            233.0                     75.0
# 4     2020-01-01  04:00:00            190.0                     70.0
# ...          ...       ...              ...                      ...
# 8779  2020-12-31  19:00:00            159.0                     82.0
# 8780  2020-12-31  20:00:00             60.0                     29.0
# 8781  2020-12-31  21:00:00             40.0                     17.0
# 8782  2020-12-31  22:00:00             31.0                     15.0
# 8783  2020-12-31  23:00:00             38.0                     20.0
#
#       Neutor FR stadtauswärts                         Wetter  Temperatur (°C)
# 0                        63.0                 Leichter Nebel              1.0  \
# 1                        99.0                 Leichter Nebel              1.0
# 2                       142.0                 Leichter Nebel              1.0
# 3                       158.0                 Leichter Nebel              1.0
# 4                       120.0                 Leichter Nebel              1.0
# ...                       ...                            ...              ...
# 8779                     77.0  Mäßige bis starke Schneefälle              2.0
# 8780                     31.0                        Bedeckt              2.0
# 8781                     23.0                        Bedeckt              2.0
# 8782                     16.0                        Bedeckt              1.0
# 8783                     18.0                        Bewölkt              0.0
#
#       Luftfeuchtigkeit (%)  Regen (mm)  Wind (km/h)
# 0                     95.0         0.0          6.0
# 1                     94.0         0.0          6.0
# 2                     94.0         0.0          5.0
# 3                     93.0         0.0          5.0
# 4                     93.0         0.0          5.0
# ...                    ...         ...          ...
# 8779                  87.0         0.0          7.0
# 8780                  87.0         0.0          7.0
# 8781                  87.0         0.0          8.0
# 8782                  88.0         0.0          7.0
# 8783                  90.0         0.0          6.0
#
# [8784 rows x 10 columns]

# %% [markdown]
# ### Daten 2021

# %%
file_path_21 = src_directory / 'Zaehlstelle_Neutor_2021_Stundenauswertung.xlsx'
neutor_xlsx_21 = pd.read_excel(file_path_21, 
                            sheet_name=None, 
                            skiprows=2,
                            skipfooter=1,
                            engine='openpyxl')

df_neutor_21 = pd.concat(neutor_xlsx_21.values(), ignore_index=True)

df_neutor_21['Datum'] = pd.to_datetime(df_neutor_21['Time'], format='%Y-%m-%d').dt.date.astype(str)
df_neutor_21['Zeit'] = pd.to_datetime(df_neutor_21['Time']).dt.time

cols_21 = list(df_neutor_21.columns.values)

df_neutor_21 = df_neutor_21[['Datum', 'Zeit', 'Neutor', 'Neutor FR stadteinwärts', 'Neutor FR stadtauswärts', 'Wetter', 'Temperatur (°C)',
                             'Luftfeuchtigkeit (%)', 'Regen (mm)', 'Wind (km/h)']]

df_neutor_21.columns = df_neutor_names

df_neutor_21
# Out:
#            Datum      Zeit  Neutor (gesamt)  Neutor FR stadteinwärts
# 0     2021-01-01  00:00:00             40.0                     16.0  \
# 1     2021-01-01  01:00:00             73.0                     27.0
# 2     2021-01-01  02:00:00            100.0                     36.0
# 3     2021-01-01  03:00:00             91.0                     51.0
# 4     2021-01-01  04:00:00             77.0                     30.0
# ...          ...       ...              ...                      ...
# 8754  2021-12-31  18:00:00            157.0                    157.0
# 8755  2021-12-31  19:00:00            142.0                    142.0
# 8756  2021-12-31  20:00:00             64.0                     64.0
# 8757  2021-12-31  21:00:00             35.0                     35.0
# 8758  2021-12-31  22:00:00             19.0                     19.0
#
#       Neutor FR stadtauswärts          Wetter  Temperatur (°C)
# 0                        24.0         Bewölkt             -1.0  \
# 1                        46.0         Bewölkt              0.0
# 2                        64.0  Leicht bewölkt              1.0
# 3                        40.0  Leicht bewölkt              1.0
# 4                        47.0  Leicht bewölkt              1.0
# ...                       ...             ...              ...
# 8754                      NaN          Sonnig             14.0
# 8755                      NaN          Sonnig             13.0
# 8756                      NaN  Leicht bewölkt             12.0
# 8757                      NaN  Leicht bewölkt             12.0
# 8758                      NaN  Leicht bewölkt             12.0
#
#       Luftfeuchtigkeit (%)  Regen (mm)  Wind (km/h)
# 0                     91.0         0.0          5.0
# 1                     92.0         0.0          5.0
# 2                     93.0         0.0          4.0
# 3                     94.0         0.0          3.0
# 4                     93.0         0.0          3.0
# ...                    ...         ...          ...
# 8754                  81.0         0.0         23.0
# 8755                  80.0         0.0         24.0
# 8756                  80.0         0.0         24.0
# 8757                  79.0         0.0         25.0
# 8758                  80.0         0.0         27.0
#
# [8759 rows x 10 columns]

# %% [markdown]
# ### Daten 2022

# %%
file_path_22 = src_directory / 'Zaehlstelle_Neutor_2022_Stundenauswertung.xlsx'
neutor_xlsx_22 = pd.read_excel(file_path_22, 
                            sheet_name=None, 
                            skiprows=2,
                            skipfooter=1,
                            engine='openpyxl')

df_neutor_22 = pd.concat(neutor_xlsx_22.values(), ignore_index=True)

df_neutor_22 = df_neutor_22.drop(columns='Unnamed: 0')

df_neutor_22['Datum'] = pd.to_datetime(df_neutor_22['Zeit'], format='%Y-%m-%d').dt.date.astype(str)
df_neutor_22['Zeit'] = pd.to_datetime(df_neutor_22['Zeit']).dt.time

cols_22 = list(df_neutor_22.columns.values)

df_neutor_22 = df_neutor_22[['Datum', 'Zeit', 'Neutor', 'Neutor FR stadteinwärts', 'Neutor FR stadtauswärts', 'Wetter', 'Temperatur (°C)',
                             'Luftfeuchtigkeit (%)', 'Regen (mm)', 'Wind (km/h)']]

df_neutor_22.columns = df_neutor_names

df_neutor_22
# Out:
#            Datum      Zeit  Neutor (gesamt)  Neutor FR stadteinwärts
# 0     2022-01-01  00:00:00             41.0                     15.0  \
# 1     2022-01-01  01:00:00             98.0                     52.0
# 2     2022-01-01  02:00:00            181.0                     82.0
# 3     2022-01-01  03:00:00            194.0                     71.0
# 4     2022-01-01  04:00:00            126.0                     39.0
# ...          ...       ...              ...                      ...
# 8754  2022-12-31  18:00:00            365.0                    173.0
# 8755  2022-12-31  19:00:00            303.0                    164.0
# 8756  2022-12-31  20:00:00            207.0                    102.0
# 8757  2022-12-31  21:00:00            149.0                     83.0
# 8758  2022-12-31  22:00:00            120.0                     71.0
#
#       Neutor FR stadtauswärts          Wetter  Temperatur (°C)
# 0                        26.0         Bedeckt             12.0  \
# 1                        46.0         Bedeckt             12.0
# 2                        99.0         Bedeckt             11.0
# 3                       123.0         Bedeckt             11.0
# 4                        87.0         Bedeckt             11.0
# ...                       ...             ...              ...
# 8754                    192.0         Bewölkt             16.0
# 8755                    139.0         Bewölkt             16.0
# 8756                    105.0  Leicht bewölkt             16.0
# 8757                     66.0  Leicht bewölkt             15.0
# 8758                     49.0  Leicht bewölkt             15.0
#
#       Luftfeuchtigkeit (%)  Regen (mm)  Wind (km/h)
# 0                     81.0         0.0         31.0
# 1                     82.0         0.0         29.0
# 2                     84.0         0.0         28.0
# 3                     85.0         0.0         26.0
# 4                     86.0         0.0         24.0
# ...                    ...         ...          ...
# 8754                  72.0         0.0         38.0
# 8755                  70.0         0.0         37.0
# 8756                  69.0         0.0         36.0
# 8757                  67.0         0.0         36.0
# 8758                  65.0         0.0         35.0
#
# [8759 rows x 10 columns]

# %%
df_neutor = pd.concat([df_neutor_18, df_neutor_19, df_neutor_20, df_neutor_21, df_neutor_22])
print(df_neutor)
# Out:
#                     Datum      Zeit  Neutor (gesamt)  Neutor FR stadteinwärts
# 0     2018-01-01 00:00:00  00:00:00             71.0                     26.0  \
# 1     2018-01-01 00:00:00  01:00:00             67.0                     35.0
# 2     2018-01-01 00:00:00  02:00:00            123.0                     53.0
# 3     2018-01-01 00:00:00  03:00:00            171.0                     64.0
# 4     2018-01-01 00:00:00  04:00:00            102.0                     26.0
# ...                   ...       ...              ...                      ...
# 8754           2022-12-31  18:00:00            365.0                    173.0
# 8755           2022-12-31  19:00:00            303.0                    164.0
# 8756           2022-12-31  20:00:00            207.0                    102.0
# 8757           2022-12-31  21:00:00            149.0                     83.0
# 8758           2022-12-31  22:00:00            120.0                     71.0
#
#       Neutor FR stadtauswärts              Wetter  Temperatur (°C)
# 0                        45.0  Leichter Regenfall             10.0  \
# 1                        32.0  Leichter Regenfall              9.0
# 2                        70.0   Mäßiger Regenfall              9.0
# 3                       107.0   Mäßiger Regenfall              8.0
# 4                        76.0   Mäßiger Regenfall              8.0
# ...                       ...                 ...              ...
# 8754                    192.0             Bewölkt             16.0
# 8755                    139.0             Bewölkt             16.0
# 8756                    105.0      Leicht bewölkt             16.0
# 8757                     66.0      Leicht bewölkt             15.0
# 8758                     49.0      Leicht bewölkt             15.0
#
#       Luftfeuchtigkeit (%)  Regen (mm)  Wind (km/h)
# 0                     83.0         1.0         26.0
# 1                     81.0         1.0         27.0
# 2                     79.0         1.0         29.0
# 3                     77.0         0.0         31.0
# 4                     75.0         0.0         32.0
# ...                    ...         ...          ...
# 8754                  72.0         0.0         38.0
# 8755                  70.0         0.0         37.0
# 8756                  69.0         0.0         36.0
# 8757                  67.0         0.0         36.0
# 8758                  65.0         0.0         35.0
#
# [43819 rows x 10 columns]

# %%
from dateutil.relativedelta import relativedelta
from dateutil.parser import parse
from datetime import datetime, timedelta, date
import pandas as pd
from pathlib import Path
import os
from os import walk
import locale

def get_src_directory(script_directory):
    src_directory = script_directory.parent / 'src'
    return src_directory


for root, dirs, files in os.walk('/Users/danielzellner/Documents/Studium/Bachelorthesis/src'):
    files = [f for f in files if not f[0] == '.']



def clean_neutor_excel(file_name):
    notebook_directory = os.getcwd()
    script_directory = Path(notebook_directory)
    src_directory = get_src_directory(script_directory)
    file_path = src_directory / file_name
    neutor_xlsx = pd.read_excel(file_path, 
                                    sheet_name=None, 
                                    skiprows=2,
                                    skipfooter=1,
                                    engine='openpyxl')
    
    df_neutor = pd.concat(neutor_xlsx.values(), ignore_index=True)
    
    new_column_names = {
                        'Neutor': 'Neutor (gesamt)',
                        'FR stadteinwärts': 'Neutor FR stadteinwärts',
                        'FR stadtauswärts': 'Neutor FR stadtauswärts',
                        'Time' : 'Zeit'
                    }
    df_neutor = df_neutor.rename(columns=new_column_names)
    
    if 'Gefühlte Temperatur (°C)' in df_neutor.columns:
        df_neutor = df_neutor.drop('Gefühlte Temperatur (°C)', axis=1)
        
    if 'Unnamed: 0' in df_neutor.columns:
        df_neutor = df_neutor.drop(columns='Unnamed: 0', axis=1)

    if 'Zeit' in df_neutor.columns:
        success_date = False

        try:
            df_neutor['Datum'] = pd.to_datetime(df_neutor['Zeit'], format='%Y-%m-%d').dt.date.astype(str)
            df_neutor['Zeit'] = pd.to_datetime(df_neutor['Zeit']).dt.time
            
            success_date = True
        except ValueError:
            print('Konnte nicht in das Foramt bereinigt werden')
        
        if not success_date:
            try:
                df_neutor['Zeit'] = df_neutor['Zeit'].astype(str)
                df_neutor[['day', 'month', 'year', 'Uhrzeit']] = df_neutor['Zeit'].str.split(' ', expand=True)

                month_to_num = {'Jan.': 1, 'Febr.': 2, 'Mrz.': 3, 'Apr.': 4, 'Mai': 5, 'Jun.': 6, 'Jul.': 7, 'Aug.': 8, 'Sept.': 9, 'Okt.': 10, 'Nov.': 11, 'Dez.': 12}
                df_neutor.month = df_neutor.month.map(month_to_num)
                df_neutor.day = df_neutor.day.astype(str)
                df_neutor.day = df_neutor.day.str.replace('.','')

                df_neutor.drop(['Zeit'], axis=True, inplace=True)
                df_neutor['Zeit'] = pd.to_datetime(df_neutor['Uhrzeit'], format='%H:%M', errors='coerce').dt.time
                df_neutor['Datum'] = pd.to_datetime(df_neutor[['year', 'month', 'day']])

                df_neutor.drop(['day','month','year', 'Uhrzeit'], axis=True, inplace=True)
                
                success_date = True
            except ValueError:
                print('Konnte nicht in das Foramt bereinigt werden')

        if success_date:          
            try:
                df_neutor = df_neutor[['Datum', 'Zeit', 'Neutor (gesamt)', 'Neutor FR stadteinwärts', 'Neutor FR stadtauswärts', 'Wetter', 'Temperatur (°C)', 
                            'Luftfeuchtigkeit (%)', 'Regen (mm)', 'Wind (km/h)']]
            except (ValueError, KeyError):
                print('Falsche Spaltenbezeichnung')
            
        return df_neutor    

df_neutor_18 = clean_neutor_excel('Zaehlstelle_Neutor_2021_Stundenauswertung.xlsx')

print(df_neutor_18)
# Out:
#            Datum      Zeit  Neutor (gesamt)  Neutor FR stadteinwärts
# 0     2021-01-01  00:00:00             40.0                     16.0  \
# 1     2021-01-01  01:00:00             73.0                     27.0
# 2     2021-01-01  02:00:00            100.0                     36.0
# 3     2021-01-01  03:00:00             91.0                     51.0
# 4     2021-01-01  04:00:00             77.0                     30.0
# ...          ...       ...              ...                      ...
# 8754  2021-12-31  18:00:00            157.0                    157.0
# 8755  2021-12-31  19:00:00            142.0                    142.0
# 8756  2021-12-31  20:00:00             64.0                     64.0
# 8757  2021-12-31  21:00:00             35.0                     35.0
# 8758  2021-12-31  22:00:00             19.0                     19.0
#
#       Neutor FR stadtauswärts          Wetter  Temperatur (°C)
# 0                        24.0         Bewölkt             -1.0  \
# 1                        46.0         Bewölkt              0.0
# 2                        64.0  Leicht bewölkt              1.0
# 3                        40.0  Leicht bewölkt              1.0
# 4                        47.0  Leicht bewölkt              1.0
# ...                       ...             ...              ...
# 8754                      NaN          Sonnig             14.0
# 8755                      NaN          Sonnig             13.0
# 8756                      NaN  Leicht bewölkt             12.0
# 8757                      NaN  Leicht bewölkt             12.0
# 8758                      NaN  Leicht bewölkt             12.0
#
#       Luftfeuchtigkeit (%)  Regen (mm)  Wind (km/h)
# 0                     91.0         0.0          5.0
# 1                     92.0         0.0          5.0
# 2                     93.0         0.0          4.0
# 3                     94.0         0.0          3.0
# 4                     93.0         0.0          3.0
# ...                    ...         ...          ...
# 8754                  81.0         0.0         23.0
# 8755                  80.0         0.0         24.0
# 8756                  80.0         0.0         24.0
# 8757                  79.0         0.0         25.0
# 8758                  80.0         0.0         27.0
#
# [8759 rows x 10 columns]

# %%
for root, dirs, files in os.walk('/Users/danielzellner/Documents/Studium/Bachelorthesis/src'):
    files = [f for f in files if not f[0] == '.']
print(files)
# Out:
# ['Zaehlstelle_Neutor_2019_Stundenauswertung.xlsx', 'Zaehlstelle_Neutor_2022_Stundenauswertung.xlsx', 'Zaehlstelle_Neutor_2021_Stundenauswertung.xlsx', 'Zaehlstelle_Neutor_2020_Stundenauswertung.xlsx', 'Zaehlstelle_Neutor_2018_Stundenauswertung.xlsx']

# %%
data = []
for i in files:
    df = clean_neutor_excel(i)
    data.append(df)

data
df_neutor = pd.concat(data, ignore_index=True)
# Out:
# Konnte nicht in das Foramt bereinigt werden

# %%
df_neutor
# Out:
#                      Datum      Zeit  Neutor (gesamt)
# 0               2019-01-01  00:00:00             88.0  \
# 1               2019-01-01  01:00:00            197.0
# 2               2019-01-01  02:00:00            302.0
# 3               2019-01-01  03:00:00            302.0
# 4               2019-01-01  04:00:00            328.0
# ...                    ...       ...              ...
# 43814  2018-12-31 00:00:00  19:00:00            397.0
# 43815  2018-12-31 00:00:00  20:00:00            191.0
# 43816  2018-12-31 00:00:00  21:00:00            125.0
# 43817  2018-12-31 00:00:00  22:00:00            101.0
# 43818  2018-12-31 00:00:00  23:00:00            192.0
#
#        Neutor FR stadteinwärts  Neutor FR stadtauswärts
# 0                         26.0                     62.0  \
# 1                         57.0                    140.0
# 2                         94.0                    208.0
# 3                        121.0                    181.0
# 4                        119.0                    209.0
# ...                        ...                      ...
# 43814                    246.0                    151.0
# 43815                     83.0                    108.0
# 43816                     68.0                     57.0
# 43817                     57.0                     44.0
# 43818                    128.0                     64.0
#
#                         Wetter  Temperatur (°C)  Luftfeuchtigkeit (%)
# 0      Stellenweiser Regenfall              8.0                  90.0  \
# 1      Stellenweiser Regenfall              8.0                  89.0
# 2                      Bedeckt              8.0                  88.0
# 3                      Bedeckt              8.0                  87.0
# 4                      Bedeckt              8.0                  87.0
# ...                        ...              ...                   ...
# 43814           Leicht bewölkt              8.0                  92.0
# 43815  Stellenweiser Regenfall              8.0                  91.0
# 43816  Stellenweiser Regenfall              8.0                  90.0
# 43817  Stellenweiser Regenfall              8.0                  90.0
# 43818  Stellenweiser Regenfall              8.0                  90.0
#
#        Regen (mm)  Wind (km/h)
# 0             0.0         20.0
# 1             0.0         21.0
# 2             0.0         23.0
# 3             0.0         24.0
# 4             0.0         25.0
# ...           ...          ...
# 43814         0.0         14.0
# 43815         0.0         15.0
# 43816         0.0         17.0
# 43817         0.0         18.0
# 43818         0.0         19.0
#
# [43819 rows x 10 columns]

# %% [markdown]
# ### Semesterferien manipulieren

# %%
import pandas as pd

# Pfad zur CSV-Datei
csv_file = 'semesterferien.csv'

# DataFrame aus CSV erstellen
df = pd.read_csv(csv_file)

# Iteration über jede Zeile des DataFrames
for index, row in df.iterrows():
    semester = row['semester']
    semester_beginn = pd.to_datetime(row['semester_beginn'])
    vorlesungsbeginn = pd.to_datetime(row['vorlesungsbeginn'])
    erster_ferientag = pd.to_datetime(row['erster_ferientag'])
    letzter_ferientag = pd.to_datetime(row['letzter_ferientag'])
    vorlesungsende = pd.to_datetime(row['vorlesungsende'])
    semesterende = pd.to_datetime(row['semesterende'])
    
    # Ausgabe der einzelnen Daten innerhalb des Zeitraums
    #print(f"Semester: {semester}")
    #print(f"Semesterbeginn: {semester_beginn}")
    #print(f"Vorlesungsbeginn: {vorlesungsbeginn}")
    
    # Ausgabe jedes einzelnen Datums innerhalb des Zeitraums
    current_date = semester_beginn
    while current_date <= semesterende:
        #print(current_date.date())
        current_date += pd.DateOffset(days=1)
    
    #print(f"Vorlesungsende: {vorlesungsende}")
    #print(f"Semesterende: {semesterende}")
    #print()

# %%
import pandas as pd

# Pfad zur CSV-Datei
csv_file = 'semesterferien.csv'

# DataFrame aus CSV erstellen
df = pd.read_csv(csv_file)

# Liste für die einzelnen Daten erstellen
data = []

# Iteration über jede Zeile des DataFrames
for index, row in df.iterrows():
    semester = row['semester']
    semester_beginn = pd.to_datetime(row['semester_beginn'])
    vorlesungsbeginn = pd.to_datetime(row['vorlesungsbeginn'])
    erster_ferientag = pd.to_datetime(row['erster_ferientag'])
    letzter_ferientag = pd.to_datetime(row['letzter_ferientag'])
    vorlesungsende = pd.to_datetime(row['vorlesungsende'])
    semesterende = pd.to_datetime(row['semesterende'])
    
    # Einzelne Daten innerhalb des Zeitraums erfassen
    current_date = vorlesungsbeginn
    while current_date <= vorlesungsende:
        data.append({'Semester': semester, 'Datum': current_date.date()})
        current_date += pd.DateOffset(days=1)

# DataFrame erstellen
result_df = pd.DataFrame(data)

# Ausgabe des resultierenden DataFrames
print(result_df)
# Out:
#           Semester       Datum
# 0        SoSe 2011  2011-04-04
# 1        SoSe 2011  2011-04-05
# 2        SoSe 2011  2011-04-06
# 3        SoSe 2011  2011-04-07
# 4        SoSe 2011  2011-04-08
# ...            ...         ...
# 2832  WiSe 2023/24  2024-01-29
# 2833  WiSe 2023/24  2024-01-30
# 2834  WiSe 2023/24  2024-01-31
# 2835  WiSe 2023/24  2024-02-01
# 2836  WiSe 2023/24  2024-02-02
#
# [2837 rows x 2 columns]

# %%
result_df['Datum'] = pd.to_datetime(result_df['Datum'], format='%Y-%m-%d').dt.date.astype(str)
result_df
# Out:
#           Semester       Datum
# 0        SoSe 2011  2011-04-04
# 1        SoSe 2011  2011-04-05
# 2        SoSe 2011  2011-04-06
# 3        SoSe 2011  2011-04-07
# 4        SoSe 2011  2011-04-08
# ...            ...         ...
# 2832  WiSe 2023/24  2024-01-29
# 2833  WiSe 2023/24  2024-01-30
# 2834  WiSe 2023/24  2024-01-31
# 2835  WiSe 2023/24  2024-02-01
# 2836  WiSe 2023/24  2024-02-02
#
# [2837 rows x 2 columns]

# %%
df_neutor['Semesterferien'] = 1
df_neutor.loc[df_neutor['Datum'].isin(result_df['Datum']), 'Semesterferien'] = 0

# %%
df_neutor
# Out:
#                      Datum      Zeit  Neutor (gesamt)
# 0               2019-01-01  00:00:00             88.0  \
# 1               2019-01-01  01:00:00            197.0
# 2               2019-01-01  02:00:00            302.0
# 3               2019-01-01  03:00:00            302.0
# 4               2019-01-01  04:00:00            328.0
# ...                    ...       ...              ...
# 43814  2018-12-31 00:00:00  19:00:00            397.0
# 43815  2018-12-31 00:00:00  20:00:00            191.0
# 43816  2018-12-31 00:00:00  21:00:00            125.0
# 43817  2018-12-31 00:00:00  22:00:00            101.0
# 43818  2018-12-31 00:00:00  23:00:00            192.0
#
#        Neutor FR stadteinwärts  Neutor FR stadtauswärts
# 0                         26.0                     62.0  \
# 1                         57.0                    140.0
# 2                         94.0                    208.0
# 3                        121.0                    181.0
# 4                        119.0                    209.0
# ...                        ...                      ...
# 43814                    246.0                    151.0
# 43815                     83.0                    108.0
# 43816                     68.0                     57.0
# 43817                     57.0                     44.0
# 43818                    128.0                     64.0
#
#                         Wetter  Temperatur (°C)  Luftfeuchtigkeit (%)
# 0      Stellenweiser Regenfall              8.0                  90.0  \
# 1      Stellenweiser Regenfall              8.0                  89.0
# 2                      Bedeckt              8.0                  88.0
# 3                      Bedeckt              8.0                  87.0
# 4                      Bedeckt              8.0                  87.0
# ...                        ...              ...                   ...
# 43814           Leicht bewölkt              8.0                  92.0
# 43815  Stellenweiser Regenfall              8.0                  91.0
# 43816  Stellenweiser Regenfall              8.0                  90.0
# 43817  Stellenweiser Regenfall              8.0                  90.0
# 43818  Stellenweiser Regenfall              8.0                  90.0
#
#        Regen (mm)  Wind (km/h)  Semesterferien
# 0             0.0         20.0               0
# 1             0.0         21.0               0
# 2             0.0         23.0               0
# 3             0.0         24.0               0
# 4             0.0         25.0               0
# ...           ...          ...             ...
# 43814         0.0         14.0               1
# 43815         0.0         15.0               1
# 43816         0.0         17.0               1
# 43817         0.0         18.0               1
# 43818         0.0         19.0               1
#
# [43819 rows x 11 columns]

# %% [markdown]
# ## Feiertage NRW

# %%
import requests

url = "https://www.spiketime.de/feiertagapi/feiertage/2018/2023"

response = requests.get(url)

if response.status_code == 200:
    data_feiertage = response.json()

    print(data_feiertage)
else:
    print("Fehler beim Abrufen der Daten von der API.")
# Out:
# [{'Datum': '2018-01-01T00:00:00', 'Feiertag': {'Name': 'Neujahr', 'Laender': [{'Name': 'Baden-Württemberg', 'Abkuerzung': 'BW'}, {'Name': 'Bayern', 'Abkuerzung': 'BY'}, {'Name': 'Berlin', 'Abkuerzung': 'BE'}, {'Name': 'Brandenburg', 'Abkuerzung': 'BB'}, {'Name': 'Bremen', 'Abkuerzung': 'HB'}, {'Name': 'Hamburg', 'Abkuerzung': 'HH'}, {'Name': 'Hessen', 'Abkuerzung': 'HE'}, {'Name': 'Mecklenburg-Vorpommern', 'Abkuerzung': 'MV'}, {'Name': 'Niedersachsen', 'Abkuerzung': 'NI'}, {'Name': 'Nordrhein-Westfalen', 'Abkuerzung': 'NW'}, {'Name': 'Rheinland-Pfalz', 'Abkuerzung': 'RP'}, {'Name': 'Saarland', 'Abkuerzung': 'SL'}, {'Name': 'Sachsen', 'Abkuerzung': 'SN'}, {'Name': 'Sachsen-Anhalt', 'Abkuerzung': 'ST'}, {'Name': 'Schleswig-Holstein', 'Abkuerzung': 'SH'}, {'Name': 'Thüringen', 'Abkuerzung': 'TH'}]}}, {'Datum': '2018-01-06T00:00:00', 'Feiertag': {'Name': 'Heilige Drei Könige', 'Laender': [{'Name': 'Baden-Württemberg', 'Abkuerzung': 'BW'}, {'Name': 'Bayern', 'Abkuerzung': 'BY'}, {'Name': 'Sachsen-Anhalt', 'Abkuerzung': 'ST'}]}}, {'Datum': '2018-03-30T00:00:00', 'Feiertag': {'Name': 'Karfreitag', 'Laender': [{'Name': 'Baden-Württemberg', 'Abkuerzung': 'BW'}, {'Name': 'Bayern', 'Abkuerzung': 'BY'}, {'Name': 'Berlin', 'Abkuerzung': 'BE'}, {'Name': 'Brandenburg', 'Abkuerzung': 'BB'}, {'Name': 'Bremen', 'Abkuerzung': 'HB'}, {'Name': 'Hamburg', 'Abkuerzung': 'HH'}, {'Name': 'Hessen', 'Abkuerzung': 'HE'}, {'Name': 'Mecklenburg-Vorpommern', 'Abkuerzung': 'MV'}, {'Name': 'Niedersachsen', 'Abkuerzung': 'NI'}, {'Name': 'Nordrhein-Westfalen', 'Abkuerzung': 'NW'}, {'Name': 'Rheinland-Pfalz', 'Abkuerzung': 'RP'}, {'Name': 'Saarland', 'Abkuerzung': 'SL'}, {'Name': 'Sachsen', 'Abkuerzung': 'SN'}, {'Name': 'Sachsen-Anhalt', 'Abkuerzung': 'ST'}, {'Name': 'Schleswig-Holstein', 'Abkuerzung': 'SH'}, {'Name': 'Thüringen', 'Abkuerzung': 'TH'}]}}, {'Datum': '2018-04-01T00:00:00', 'Feiertag': {'Name': 'Ostersonntag', 'Laender': [{'Name': 'Baden-Württemberg', 'Abkuerzung': 'BW'}, {'Name': 'Bayern', 'Abkuerzung': 'BY'}, {'Name': 'Berlin', 'Abkuerzung': 'BE'}, {'Name': 'Brandenburg', 'Abkuerzung': 'BB'}, {'Name': 'Bremen', 'Abkuerzung': 'HB'}, {'Name': 'Hamburg', 'Abkuerzung': 'HH'}, {'Name': 'Hessen', 'Abkuerzung': 'HE'}, {'Name': 'Mecklenburg-Vorpommern', 'Abkuerzung': 'MV'}, {'Name': 'Niedersachsen', 'Abkuerzung': 'NI'}, {'Name': 'Nordrhein-Westfalen', 'Abkuerzung': 'NW'}, {'Name': 'Rheinland-Pfalz', 'Abkuerzung': 'RP'}, {'Name': 'Saarland', 'Abkuerzung': 'SL'}, {'Name': 'Sachsen', 'Abkuerzung': 'SN'}, {'Name': 'Sachsen-Anhalt', 'Abkuerzung': 'ST'}, {'Name': 'Schleswig-Holstein', 'Abkuerzung': 'SH'}, {'Name': 'Thüringen', 'Abkuerzung': 'TH'}]}}, {'Datum': '2018-04-02T00:00:00', 'Feiertag': {'Name': 'Ostermontag', 'Laender': [{'Name': 'Baden-Württemberg', 'Abkuerzung': 'BW'}, {'Name': 'Bayern', 'Abkuerzung': 'BY'}, {'Name': 'Berlin', 'Abkuerzung': 'BE'}, {'Name': 'Brandenburg', 'Abkuerzung': 'BB'}, {'Name': 'Bremen', 'Abkuerzung': 'HB'}, {'Name': 'Hamburg', 'Abkuerzung': 'HH'}, {'Name': 'Hessen', 'Abkuerzung': 'HE'}, {'Name': 'Mecklenburg-Vorpommern', 'Abkuerzung': 'MV'}, {'Name': 'Niedersachsen', 'Abkuerzung': 'NI'}, {'Name': 'Nordrhein-Westfalen', 'Abkuerzung': 'NW'}, {'Name': 'Rheinland-Pfalz', 'Abkuerzung': 'RP'}, {'Name': 'Saarland', 'Abkuerzung': 'SL'}, {'Name': 'Sachsen', 'Abkuerzung': 'SN'}, {'Name': 'Sachsen-Anhalt', 'Abkuerzung': 'ST'}, {'Name': 'Schleswig-Holstein', 'Abkuerzung': 'SH'}, {'Name': 'Thüringen', 'Abkuerzung': 'TH'}]}}, {'Datum': '2018-03-08T00:00:00', 'Feiertag': {'Name': 'Internationaler Frauentag', 'Laender': []}}, {'Datum': '2018-05-01T00:00:00', 'Feiertag': {'Name': 'Erster Mai', 'Laender': [{'Name': 'Baden-Württemberg', 'Abkuerzung': 'BW'}, {'Name': 'Bayern', 'Abkuerzung': 'BY'}, {'Name': 'Berlin', 'Abkuerzung': 'BE'}, {'Name': 'Brandenburg', 'Abkuerzung': 'BB'}, {'Name': 'Bremen', 'Abkuerzung': 'HB'}, {'Name': 'Hamburg', 'Abkuerzung': 'HH'}, {'Name': 'Hessen', 'Abkuerzung': 'HE'}, {'Name': 'Mecklenburg-Vorpommern', 'Abkuerzung' ...

# %%
import json

df_feiertage = pd.json_normalize(data_feiertage)
df_feiertage = df_feiertage[df_feiertage['Feiertag.Laender'].apply(lambda x: any(entry['Name'] == 'Nordrhein-Westfalen' for entry in x))]
df_feiertage = df_feiertage.drop('Feiertag.Laender', axis=1)

print(df_feiertage)
# Out:
#                    Datum              Feiertag.Name
# 0    2018-01-01T00:00:00                    Neujahr
# 2    2018-03-30T00:00:00                 Karfreitag
# 3    2018-04-01T00:00:00               Ostersonntag
# 4    2018-04-02T00:00:00                Ostermontag
# 6    2018-05-01T00:00:00                 Erster Mai
# ..                   ...                        ...
# 100  2023-06-08T00:00:00               Fronleichnam
# 104  2023-10-03T00:00:00  Tag der deutschen Einheit
# 105  2023-11-01T00:00:00              Allerheiligen
# 106  2023-12-25T00:00:00           1. Weihnachtstag
# 107  2023-12-26T00:00:00           2. Weihnachtstag
#
# [78 rows x 2 columns]
